# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-4-5-sonnet"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }
    if system:
        params["system"] = system
    if stop_sequences:
        params["stop_sequences"] = stop_sequences
    
    response = client.messages.create(**params)
    return response.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()
print(dataset)
# Out:
# [{'task': 'Write a Python function that parses an AWS ARN string and returns a dictionary containing the partition, service, region, account-id, and resource components.'}, {'task': 'Create a JSON object for an AWS S3 bucket policy that allows read-only access to all objects in the bucket for a specific IAM role ARN.'}, {'task': 'Write a regular expression that validates AWS EC2 instance IDs (format: i-xxxxxxxxxxxxxxxxx where x is a hexadecimal character).'}]

# %%
with open('dataset.json', 'w') as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)
    
    # TODO - Grading
    score = 10
    
    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []
    
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "I'll write a Python function to parse AWS ARN (Amazon Resource Name) strings.\n\n```python\ndef parse_arn(arn_string):\n    \"\"\"\n    Parse an AWS ARN string and return its components as a dictionary.\n    \n    ARN format: arn:partition:service:region:account-id:resource\n    \n    Args:\n        arn_string (str): The ARN string to parse\n        \n    Returns:\n        dict: A dictionary containing the ARN components:\n            - partition: AWS partition (e.g., 'aws', 'aws-cn', 'aws-us-gov')\n            - service: AWS service (e.g., 's3', 'ec2', 'iam')\n            - region: AWS region (e.g., 'us-east-1', can be empty for global services)\n            - account_id: AWS account ID (12-digit number, can be empty for some services)\n            - resource: Resource identifier (format varies by service)\n            \n    Raises:\n        ValueError: If the ARN string is invalid\n    \"\"\"\n    if not arn_string:\n        raise ValueError(\"ARN string cannot be empty\")\n    \n    if not arn_string.startswith(\"arn:\"):\n        raise ValueError(\"ARN must start with 'arn:'\")\n    \n    # Split the ARN into components\n    parts = arn_string.split(\":\", 5)\n    \n    if len(parts) < 6:\n        raise ValueError(f\"Invalid ARN format. Expected at least 6 components, got {len(parts)}\")\n    \n    return {\n        \"partition\": parts[1],\n        \"service\": parts[2],\n        \"region\": parts[3],\n        \"account_id\": parts[4],\n        \"resource\": parts[5]\n    }\n\n\n# Example usage and test cases\nif __name__ == \"__main__\":\n    # Test cases with various ARN formats\n    test_arns = [\n        # S3 bucket (no region or account in ARN)\n        \"arn:aws:s3:::my-bucket\",\n        \n        # S3 object\n        \"arn:aws:s3:::my-bucket/path/to/object.txt\",\n        \n        # EC2 instance\n        \"arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0\",\n        \n        # IAM user (global service, no region)\n        \"arn:aws:iam::123456789012:user/JohnDoe\",\n        \n        # Lambda function\n        \"arn:aws:lambda:us-west-2:123456789012:function:my-function\",\n        \n        # DynamoDB table\n        \"arn:aws:dynamodb:us-east-1:123456789012:table/MyTable\",\n        \n        # China partition\n        \"arn:aws-cn:s3:::my-china-bucket\",\n        \n        # Resource with colons in the resource part\n        \"arn:aws:logs:us-east-1:123456789012:log-group:/aws/lambda/my-function:*\"\n    ]\n    \n    print(\"Testing ARN Parser:\\n\")\n    for arn in test_arns:\n        print(f\"ARN: {arn}\")\n        try:\n            result = parse_arn(arn)\n            print(f\"  Partition:  {result['partition']}\")\n            print(f\"  Service:    {result['service']}\")\n            print(f\"  Region:     {result['region'] if result['region'] else '(empty)'}\")\n            print(f\"  Account ID: {result['account_id'] if result['account_id'] else '(empty)'}\")\n            print(f\"  Resource:   {result['resource']}\")\n        except ValueError as e:\n            print(f\"  Error: {e}\")\n        print()\n    \n    # Test invalid ARNs\n    print(\"\\nTesting invalid ARNs:\")\n    invalid_arns = [\n        \"\",\n        \"not-an-arn\",\n        \"arn:aws:s3\",  # Too few components\n        \"",
#     "test_case": {
#       "task": "Write a Python function that parses an AWS ARN string and returns a dictionary containing the partition, service, region, account-id, and resource components."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS S3 Bucket Policy for Read-Only Access\n\nHere's a JSON object for an S3 bucket policy that grants read-only access to a specific IAM role:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"AllowReadOnlyAccessForSpecificRole\",\n      \"Effect\": \"Allow\",\n      \"Principal\": {\n        \"AWS\": \"arn:aws:iam::123456789012:role/YourRoleName\"\n      },\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\",\n        \"s3:ListBucket\"\n      ],\n      \"Resource\": [\n        \"arn:aws:s3:::your-bucket-name\",\n        \"arn:aws:s3:::your-bucket-name/*\"\n      ]\n    }\n  ]\n}\n```\n\n## Key Components:\n\n1. **Principal**: Replace `arn:aws:iam::123456789012:role/YourRoleName` with your actual IAM role ARN\n   - `123456789012` = Your AWS account ID\n   - `YourRoleName` = The name of your IAM role\n\n2. **Actions** (Read-only permissions):\n   - `s3:GetObject` - Retrieve objects from the bucket\n   - `s3:GetObjectVersion` - Retrieve specific versions of objects (if versioning is enabled)\n   - `s3:ListBucket` - List objects in the bucket\n\n3. **Resources**: Replace `your-bucket-name` with your actual bucket name\n   - First resource (without `/*`) - Applies to bucket-level operations (ListBucket)\n   - Second resource (with `/*`) - Applies to object-level operations (GetObject)\n\n## Example with Real Values:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"AllowReadOnlyAccessForSpecificRole\",\n      \"Effect\": \"Allow\",\n      \"Principal\": {\n        \"AWS\": \"arn:aws:iam::998877665544:role/DataAnalystRole\"\n      },\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\",\n        \"s3:ListBucket\"\n      ],\n      \"Resource\": [\n        \"arn:aws:s3:::my-company-data-bucket\",\n        \"arn:aws:s3:::my-company-data-bucket/*\"\n      ]\n    }\n  ]\n}\n```\n\nThis policy ensures the specified IAM role can only read from the bucket and cannot modify, delete, or upload objects.",
#     "test_case": {
#       "task": "Create a JSON object for an AWS S3 bucket policy that allows read-only access to all objects in the bucket for a specific IAM role ARN."
#     },
#     "score": 10
#   },
#   {
#     "output": "I'll help you write a regular expression to validate AWS EC2 instance IDs.\n\n## Regular Expression\n\n```regex\n^i-[0-9a-f]{17}$\n```\n\n## Explanation\n\n- `^` - Start of string anchor\n- `i-` - Literal characters \"i-\"\n- `[0-9a-f]` - Character class matching hexadecimal digits (0-9 and a-f)\n- `{17}` - Exactly 17 occurrences of the previous character class\n- `$` - End of string anchor\n\n## Usage Examples\n\n### JavaScript\n```javascript\nconst ec2InstanceIdRegex = /^i-[0-9a-f]{17}$/;\n\nconsole.log(ec2InstanceIdRegex.test('i-1234567890abcdef0')); // true\nconsole.log(ec2InstanceIdRegex.test('i-0123456789abcdef0')); // true\nconsole.log(ec2InstanceIdRegex.test('i-123'));                // false\nconsole.log(ec2InstanceIdRegex.test('i-ABCDEF123456789'));    // false (uppercase)\n```\n\n### Python\n```python\nimport re\n\nec2_instance_id_regex = r'^i-[0-9a-f]{17}$'\n\nprint(re.match(ec2_instance_id_regex, 'i-1234567890abcdef0'))  # Match\nprint(re.match(ec2_instance_id_regex, 'i-0123456789abcdef0'))  # Match\nprint(re.match(ec2_instance_id_regex, 'i-123'))                 # None\n```\n\n## Note on Case Sensitivity\n\nIf you want to also accept uppercase hexadecimal characters (A-F), use:\n```regex\n^i-[0-9a-fA-F]{17}$\n```\n\nOr with case-insensitive flag:\n```regex\n^i-[0-9a-f]{17}$/i\n```\n\nHowever, AWS typically uses lowercase hexadecimal characters in instance IDs, so the first version is more accurate.",
#     "test_case": {
#       "task": "Write a regular expression that validates AWS EC2 instance IDs (format: i-xxxxxxxxxxxxxxxxx where x is a hexadecimal character)."
#     },
#     "score": 10
#   }
# ]
